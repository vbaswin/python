# %%
# pandas for preprocessing technique
import pandas as pd # so we don't need to write pandas everywhere
nba=pd.read_csv('nba.csv')# .read_csv to read the csv file , nba is a dataframe where all the data sets are there
#Here we are not using squeeze or uscols type attribute and 
#by looking at the data set it is clear that it contains missing value NaN
#we are going to pre process this before actual modelling.
nba.head() # .head gives the first 5 entries
# nba.head(10) gives first 10 entries
# nba.tail(10) gives the last 5 entries

# the first line in csv file is attrbutes
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.index # .index gives the indexing information 
nba.shape # .shape gives the rows and columns ~> matrix
nba.dtypes # .dtypes gives the datatypes of the attributes

# Below are some attributes which are made for Dataframes only

nba.columns # .columns gives the name of columns
nba.axes # .axes gives a combination of index and columns
nba.info() # ~> very imp .info gives info on class, rangeindex, data columns, non-null count, dtype, memory usage   
# nba.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
# nba.get_dtype_counts() this is depricated and we get error in the newer versions so use below
nba.dtypes.value_counts()
# Out:
# object     5
# float64    4
# dtype: int64

# %% [markdown]
# # shared method and column access in pandas

# %%
import pandas as pd
rev=pd.read_csv('revenue.csv', index_col='Date'' # index_col to convert a column to index)
rev.head()
# Out:
#   File "/tmp/ipykernel_1149174/1668550310.py", line 2
#     rev=pd.read_csv('revenue.csv', index_col='Date'' # index_col to convert a column to index)
#                                                                                               ^
# SyntaxError: EOL while scanning string literal

# %%
# rev.sum() # .sum() data is added column wise
# rev.sum(axis=0) # .sum(axis=0) adds column wise
rev.sum(axis='index')

# %%
rev.sum(axis=1) # .sum(axis=1) adds data horizontally ie; row wise
# rev.sum(axis='columns')

# %%
# pnadas 2 types: series(for 1 column) and dataframe(multiple column) 
# we use only dataframe because we need to deal with multiple columns 

nba=pd.read_csv('nba.csv')
nba.head()
 
#If i want to extract data column wise
# type(nba.Salary) # type gives series type . salary is a column in the table
# Its data type is series as it is a single dimension array it works properly when there is no space in column name
# combination of series data frame

# %%
type(nba.Name) # name is also another column in type series

# %%
# nba['Name'] #It is more accurate as it works for those column also which have space in there name
nba.Name # gives the values in the name column

# %%
nba['Team'] # shows only the values of column team
nba[['Team', 'Name']] # shows values of both column Team and name
# select=['Team', 'Name']
# nba[select]

# %% [markdown]
# # Add new column to data frames

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
nba['Sports']='Basket Ball' # adds new column Sports and assigns all its values to be basket ball
#One method to add column but by this column is added at the last
nba.head()

# %%
nba=pd.read_csv('nba.csv')
#Insert method : any specific place you may add your column
# nba.insert(3, column="League", value="IPL") # .insert to insert a new column
# nba.League[[0,1]]=["Hello","test"] # .League to change the values of a particular index positions in a column
nba.head()

# %% [markdown]
# # BroadCasting operation in pandas

# %%
#Broadcasting : means to perform operation in whole series of a column
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
nba['Salary'].sub(50000) # .sub for subtraction 
# here all the values of column salary gets subtracted from 50000
# nba['Salary']-50000


nba['Age'].add(5) # .add for adding all the values of the column with 5 
nba['Age']+5


# nba['Weight'].mul(0.453)
# nba['Weight']*0.453


nba["Weight in KG"]=nba['Weight']*0.453592
nba.head()

# %% [markdown]
# # Drops Rows with Null Values

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
nba.tail()

# %%
nba.dropna() # .dropna() deletes all the values with null values
# nba.dropna(how='any', inplace = True) # default how = any
# Case sensitive ==> True not true
nba.dropna(how='all', inplace=True) # the changes will be committed with the inplace command
nba.tail()
# After this use nba.dropna(how='all') the 457 will not be present as the change is already committed to redo it we need to read the above cells once again

# %%
nba.dropna(axis=1, inplace=True) #It deletes column which consists NaN
nba.head()

# %%
nba.dropna(subset=['Salary'])

# %% [markdown]
# # fillna method for Null Values

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
nba.fillna(0).head() # .fillna to fill the null values

# %%
nba['Salary']
nba['Salary'].fillna(0, inplace=True)
nba.head()

# %%
nba['College'].fillna('No College', inplace=True) # so we can use No college instead of 0 in place of college column 
nba

# %% [markdown]
# # sort_values() method in Data Frames

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
nba.sort_values('Name', ascending=False).head()# .sort_values to sort all the values of a column
# ascending false so it will sort in the descending order

# %%
nba.sort_values('Age')
nba.sort_values('Age', ascending=False)

# %%
nba.sort_values('Salary') #NaN values would arrange at the end
# nba.sort_values('Salary', na_position='last')
nba.sort_values('Salary', na_position='first')

# %% [markdown]
# # sortvalues() for multi columns in pandas

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
nba.sort_values(['Team', 'Name'])
# nba.sort_values(['Team', 'Name'], ascending=[True,False])

# %% [markdown]
# # rank() method in pandas

# %%
import pandas as pd
nba=pd.read_csv('nba.csv').dropna(how='all')
nba['Salary']=nba['Salary'].fillna(0).astype('int')
nba.head()

# %%
#I want to decide on the basis of salary, that whose salary is highest comes at rank 1 and so on..
nba['Salary'].rank()# rank the list according to the rank of a particular column
# nba['Salary'][91]
nba['Salary'].rank(ascending=False).astype(int)
nba['Salary Rank']=nba['Salary'].rank(ascending=False).astype(int)
nba.sort_values(by='Salary', ascending=False)
# nba.head()

# %% [markdown]
# # Filtering DataFrames in pandas

# %%
import pandas as pd
df=pd.read_csv('employees.csv')
df.head() # Returns the first 5 rows of the dataframe

# %%
df.info() #at the end size is there, when we look at the output it is claer that start date and last login time data type is object, but actually they are object iof adte time same as in Senior management has object type but actually it is bool and if correct data type is not there then more memory is required
# this prints information about a DataFrame including the index dtype and columns, non-null values and memory usage

# %%
df['Start Date']

# %%
# pd.to_datetime(df['Start Date'])
df['Start Date']=pd.to_datetime(df['Start Date'])

# %%
df['Last Login Time'].head()

# %%
# pd.to_datetime(df['Last Login Time'])
df['Last Login Time']=pd.to_datetime(df['Last Login Time'])

# %%
df['Senior Management']=df['Senior Management'].astype(bool)

# %%
df['Gender']=df['Gender'].astype('category')

# %%
df.info()

# %%
#date time can be converted by attribute parse_date available in read_csv method
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.info()

# %% [markdown]
# # Filtering a dataframe based on condition

# %%
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()

# %%
#If i want to apply condition on gender that i want only those value in gender series which are of male category
# df['Gender']
df['mask']=df['Gender']=='Male'
df
# df[mask]
# df[df['Gender']=='Female'] #This will extract only those value in a column whose value are male

# %%
mask1=df['Team']=='Finance'# all the values = finance in column will be considered true
mask2=df['Gender']=='Male' # all the values = male in column gender will be considered true

# df['Filter']=df[mask1 & mask2]
df[mask1]
df[df['Team']=='Finance']

# %%
mask=df['Senior Management']
# df[df['Senior Management']] #As senior management data is already in boolean so it can be done directly'
df[mask]

# %%
mask= df['Team'] != 'Marketing'
df[mask]
# df[df['Team'] != 'Marketing'] #condition for not equal to.

# %%
df[df['Salary']>110000]

# %% [markdown]
# # Filter Data Frame with AND & OR Operators

# %%
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()

# %%
mask1=df['Gender']=='Male'
mask2=df['Team']=='Marketing'

df[mask1 & mask2] # select the rows with both the masks

df[mask1 & mask2].head()

# %%
mask3=df['Senior Management']
mask4=df['Start Date']< '1990-01-01'

df[mask3 | mask4]

# %%
mask5=df['First Name']=='Robert'
mask6=df['Team']=='Client Services'
mask7=df['Start Date']>'2016-06-01'

df[(mask5 & mask6) | mask7]

# %% [markdown]
# # isin() method in pandas

# %%
# to convert the object column into proper data types
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
# pase_dates will be typecasted to date_time ie; date and time
df['Gender']=df['Gender'].astype('category') # to typecast into category
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
# filtering out the rows with legal or sales or product in the column team
mask1=df['Team']=='Legal'
mask2=df['Team']=='Sales'
mask3=df['Team']=='Product'

df[mask1 | mask2 | mask3].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2021-08-22 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2021-08-22 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2021-08-22 15:19:00  102508   12.637
# 13       Gary    Male 2008-01-27 2021-08-22 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2021-08-22 06:09:00   59414    1.256
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# 15              False  Product

# %%
#As in above case it is claer that it requires same code for many times so it can be deal with the help of isin() method as in this case we are able to pass multiple arguments

df['Team'].isin(['Legal', 'Sales', 'Product'])

# %%
mask=df['Team'].isin(['Legal', 'Sales', 'Product'])
df[mask] #It is clear that we does not required multiple lines of asme type
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2021-08-22 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2021-08-22 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2021-08-22 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2021-08-22 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2021-08-22 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2021-08-22 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2021-08-22 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2021-08-22 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2021-08-22 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2021-08-22 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# ...

# %% [markdown]
# # isnull(), notnull() ,between() and duplicate() method in panda

# %%
# .isnull() outputs a boolean value after checking if there is a null value or not
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time']) # parse_dates to convert date and time
df['Gender']=df['Gender'].astype('category') # stype for type casting
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
#isnull() if you want to extract all the null values
mask=df['Team'].isnull()
df[mask]
# Masks are ’Boolean’ arrays – that is arrays of true and false values and provide a powerful and flexible method to selecting data.
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2021-08-22 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2021-08-22 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2021-08-22 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2021-08-22 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2021-08-22 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2021-08-22 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2021-08-22 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2021-08-22 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2021-08-22 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2021-08-22 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2021-08-22 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2021-08-22 06:06:00   66067   10.957
# ...

# %%
mask1=df['Team'].isnull()
mask2=df['Gender'].isnull()


df [ mask1 & mask2] # extract where both gender and team column has null values
# df[df['Team'].notnull()]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 91       James    NaN 2005-01-26 2021-08-22 23:00:00  128771    8.309
# 669     Joseph    NaN 1982-03-28 2021-08-22 13:05:00   86564   11.879
# 826        NaN    NaN 1988-08-01 2021-08-22 01:35:00   87103    5.665
# 855    Phillip    NaN 2003-10-20 2021-08-22 11:09:00   89700    2.277
#
#      Senior Management Team
# 91               False  NaN
# 669               True  NaN
# 826               True  NaN
# 855               True  NaN

# %%
#between()
# df['Salary'].between(60000, 70000)
df[df['Salary'].between(60000, 70000)]# filter some values lying between a range
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2021-08-22 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2021-08-22 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2021-08-22 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2021-08-22 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2021-08-22 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2021-08-22 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2021-08-22 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2021-08-22 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2021-08-22 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2021-08-22 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# ...

# %%
df['Bonus %'].between(2.0, 5.0)
df[df['Bonus %'].between(2.0, 5.0)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2021-08-22 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2021-08-22 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2021-08-22 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2021-08-22 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2021-08-22 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2021-08-22 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2021-08-22 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2021-08-22 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2021-08-22 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2021-08-22 17:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True           NaN
# 20                True         Legal
# ...

# %%
df['Start Date'].between("1991-01-01", "1992-01-01")
df[df['Start Date'].between("1991-01-01", "1992-01-01")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11 2021-08-22 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2021-08-22 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2021-08-22 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2021-08-22 20:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14 2021-08-22 02:24:00  124488   14.837
# 166        NaN  Female 1991-07-09 2021-08-22 18:52:00   42341    7.014
# 172       Sara  Female 1991-09-23 2021-08-22 18:17:00   97058    9.402
# 220        NaN  Female 1991-06-17 2021-08-22 12:49:00   71945    5.560
# 245     Victor    Male 1991-04-11 2021-08-22 07:44:00   70817   17.138
# 277     Brenda     NaN 1991-05-29 2021-08-22 06:32:00   82439   19.062
# 313       Judy  Female 1991-07-01 2021-08-22 02:33:00  109510   13.457
# 328     Samuel    Male 1991-12-19 2021-08-22 02:54:00   76076    5.319
# ...

# %%
#duplicate() method
df.sort_values('First Name', inplace=True)
# df['First Name']=df.sort_values('First Name')
df['First Name']
# Out:
# 101    Aaron
# 327    Aaron
# 440    Aaron
# 937    Aaron
# 137     Adam
#        ...
# 902      NaN
# 925      NaN
# 946      NaN
# 947      NaN
# 951      NaN
# Name: First Name, Length: 1000, dtype: object

# %%
df['First Name'].duplicated(keep='first') #it says that first value is not duplicate as in parameter it has keept it as first =first you may change it to last also
# keep='last' then default keep is last then the other duplicates above are taken as true
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %%
 df[df['First Name'].duplicated(keep=False)].head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2021-08-22 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2021-08-22 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2021-08-22 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2021-08-22 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2021-08-22 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
mask = ~ df[df['First Name'].duplicated(keep=False)].head() #reverse operation of duplicate so ir gives unique value from data sets

# %%
#drop duplicate method\
len(df)

# %%
len(df.drop_duplicates())

# %%
df.drop_duplicates(subset=['First Name'], keep='first')
len( df.drop_duplicates(subset=['First Name'], keep='first'))

# %%
df.drop_duplicates(subset=['First Name', 'Team'], keep='last').head()

# %% [markdown]
# # Retrieve row values using loc() method in pandas

# %%
# one of the most important methods
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film') # index_col which column you want to make as the index column
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc['Casino Royale'] # .loc[] we want to extract the info by string
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc['GoldenEye']

# %%
bond.loc['Casino Royale']

# %%
bond.loc['Diamonds are Forever': 'Moonracker'] # want to extract all the values from[ 1; to 2]
bond.loc['GoldenEye':] # here form golden eye to last as the last is not specified
bond.loc[: "On Her Majesty's Secret Services"] # here till first since the starting is not specified
# when we are using string and loc the last value is not removed it is also included
# Out:
#                                  Year           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# Dr. No                           1962    Sean Connery    Terence Young
# For Your Eyes Only               1981     Roger Moore        John Glen
# From Russia with Love            1963    Sean Connery    Terence Young
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton        John Glen
# Live and Let Die                 1973     Roger Moore     Guy Hamilton
# ...

# %%
bond.loc[["For Your Eyes Only", "Live and Let Die"]] # extract info of 2 values
# Out:
#                     Year        Actor      Director  Box Office  Budget  \
# Film
# For Your Eyes Only  1981  Roger Moore     John Glen       449.4    60.2
# Live and Let Die    1973  Roger Moore  Guy Hamilton       460.3    30.8
#
#                     Bond Actor Salary
# Film
# For Your Eyes Only                NaN
# Live and Let Die                  NaN

# %% [markdown]
# #  Retrieve row values using iloc() method in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv')
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
# bond.loc[15] 
bond.iloc[15] # we want to extract the info by index
# Out:
# Film                 A View to a Kill
# Year                             1985
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 15, dtype: object

# %%
bond.iloc[[15,20]]
bond.iloc[:4]
bond.iloc[4:8]
bond.iloc[0:20:2] # 0 to 19 with stepsize 2
# Out:
#                                Film  Year           Actor         Director  \
# 0                            Dr. No  1962    Sean Connery    Terence Young
# 2                        Goldfinger  1964    Sean Connery     Guy Hamilton
# 4                     Casino Royale  1967     David Niven       Ken Hughes
# 6   On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
# 8                  Live and Let Die  1973     Roger Moore     Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore    Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore        John Glen
# 14                        Octopussy  1983     Roger Moore        John Glen
# 16             The Living Daylights  1987  Timothy Dalton        John Glen
# 18                        GoldenEye  1995  Pierce Brosnan  Martin Campbell
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 2        820.4    18.6                3.2
# ...

# %% [markdown]
# # Retrive row values using ix() methods in pandas

# %%
# In case of ix it has both the capability of loc and iloc
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

# %%
bond.loc['GoldenEye']
bond.ix['GoldenEye']

# %%
bond.ix[[ 'Moonraker', 'Spectre']]

# %%
'Spectre' in bond.index
'Sacred Bond' in bond.index
bond.index
bond.values

# %%
bond.ix[0] #It shows that ix will be taken data as loc and iloc both

# %% [markdown]
# # Second argument of iloc, loc and ix methods

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

# %%
bond.loc['Moonraker', 'Actor']
# bond.loc['Moonraker', 'Director']
# bond.loc['Moonraker', 'Actor':'Budget']
bond.loc['Moonraker', ['Year', 'Director', 'Budget']]
# #Similarly we can use it with iloc and ix

# %% [markdown]
# # Set new values or a specific cell or Row in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

# %%
bond.ix['Dr. No']

# %%
#For eg i want to change the name of the actor
bond.ix['Dr. No', 'Actor']='Sir Sean Connery'
bond.ix['Dr. No', 'Actor']

# %%
bond.ix['Dr. No', ['Box Office', 'Budget', 'Bond Actor Salary']]=[470, 9, 6]

# %%
bond.ix['Dr. No']

# %% [markdown]
# # Set Multiple values in DataFrames in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

# %%
mask=bond['Actor']=='Sean Connery'
bond[mask]
# Out:
#                      Film  Year         Actor        Director  Box Office  \
# 0                  Dr. No  1962  Sean Connery   Terence Young       448.8
# 1   From Russia with Love  1963  Sean Connery   Terence Young       543.8
# 2              Goldfinger  1964  Sean Connery    Guy Hamilton       820.4
# 3             Thunderball  1965  Sean Connery   Terence Young       848.1
# 5     You Only Live Twice  1967  Sean Connery   Lewis Gilbert       514.2
# 7    Diamonds Are Forever  1971  Sean Connery    Guy Hamilton       442.5
# 13  Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0
#
#     Budget  Bond Actor Salary
# 0      7.0                0.6
# 1     12.6                1.6
# 2     18.6                3.2
# 3     41.9                4.7
# 5     59.9                4.4
# 7     34.7                5.8
# 13    86.0                NaN

# %%
bond[mask]['Actor']='Sir Sean Connery'

# %%
df2=bond[mask]
df2['Actor']='Sir Sean Connery'
df2

# %%
bond

# %%
bond.ix[mask]
bond.ix[mask,'Actor']='Sir Sean Connery'
bond

# %% [markdown]
# # Rename Index Labels or Columns in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

# %%
bond.rename(columns={'Year':'Release date', 'Box Office' : 'Revenue'}, inplace=True) 
#.rename(columns= {now: what you want to change it to})
# inplace=true is required to commit it
bond.head()
# Out:
#                     Film  Release date         Actor       Director  Revenue  \
# 0                 Dr. No          1962  Sean Connery  Terence Young    448.8
# 1  From Russia with Love          1963  Sean Connery  Terence Young    543.8
# 2             Goldfinger          1964  Sean Connery   Guy Hamilton    820.4
# 3            Thunderball          1965  Sean Connery  Terence Young    848.1
# 4          Casino Royale          1967   David Niven     Ken Hughes    315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.rename(index={'Dr. No':'Doctor No', 'GoldenEye':'Golden Eye','The World Is Not Enough': 'Best Bond Movie'})

# %% [markdown]
# # Query Methods in Pandas

# %%
#Query methods only applys when all the column are strings and no space in between columns name

import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

# %%
bond.columns=[column_names.replace(" ",  "_") for column_names in bond.columns]
bond.head()

# %%
bond.query('Actor=="Sean Connery"')
# Out:
#                      Film  Release date         Actor        Director  \
# 0                  Dr. No          1962  Sean Connery   Terence Young
# 1   From Russia with Love          1963  Sean Connery   Terence Young
# 2              Goldfinger          1964  Sean Connery    Guy Hamilton
# 3             Thunderball          1965  Sean Connery   Terence Young
# 5     You Only Live Twice          1967  Sean Connery   Lewis Gilbert
# 7    Diamonds Are Forever          1971  Sean Connery    Guy Hamilton
# 13  Never Say Never Again          1983  Sean Connery  Irvin Kershner
#
#     Revenue  Budget  Bond Actor Salary
# 0     448.8     7.0                0.6
# 1     543.8    12.6                1.6
# 2     820.4    18.6                3.2
# 3     848.1    41.9                4.7
# 5     514.2    59.9                4.4
# 7     442.5    34.7                5.8
# 13    380.0    86.0                NaN

# %%
bond.query("Director=='Terence Young'")

# %%
bond.query("Actor != 'Roger Moore'")
# Out:
#                                Film  Release date           Actor  \
# 0                            Dr. No          1962    Sean Connery
# 1             From Russia with Love          1963    Sean Connery
# 2                        Goldfinger          1964    Sean Connery
# 3                       Thunderball          1965    Sean Connery
# 4                     Casino Royale          1967     David Niven
# 5               You Only Live Twice          1967    Sean Connery
# 6   On Her Majesty's Secret Service          1969  George Lazenby
# 7              Diamonds Are Forever          1971    Sean Connery
# 13            Never Say Never Again          1983    Sean Connery
# 16             The Living Daylights          1987  Timothy Dalton
# 17                  Licence to Kill          1989  Timothy Dalton
# 18                        GoldenEye          1995  Pierce Brosnan
# 19              Tomorrow Never Dies          1997  Pierce Brosnan
# ...

# %%
bond.query("Revenue>600")
# Out:
#            Film  Release date         Actor       Director  Revenue  Budget  \
# 2    Goldfinger          1964  Sean Connery   Guy Hamilton    820.4    18.6
# 3   Thunderball          1965  Sean Connery  Terence Young    848.1    41.9
# 24      Skyfall          2012  Daniel Craig     Sam Mendes    943.5   170.2
# 25      Spectre          2015  Daniel Craig     Sam Mendes    726.7   206.3
#
#     Bond Actor Salary
# 2                 3.2
# 3                 4.7
# 24               14.5
# 25                NaN

# %%
bond.query("Actor=='Roger Moore' and Director=='John Glen'")
